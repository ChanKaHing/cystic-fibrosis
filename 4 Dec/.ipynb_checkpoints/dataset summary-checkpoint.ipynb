# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates
import seaborn as sns

# %%
import pandas as pd
import os

def Pearson(df, name):
    plt.figure(figsize=(15,15))
    cm = np.corrcoef(df.iloc[:,3:8].values.T)
    sns.set(font_scale=1.5)
    hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 25}, cmap='viridis',yticklabels=df.columns[3:8], xticklabels=df.columns[3:8])
    hm.set_title(name)
    plt.show()

# %%
df_mouse_b_enac = pd.read_csv('mouse_b_enac_summary_new.csv')
df_mouse_b_enac.shape
# Out:
# (28, 8)

# %%
df_mouse_mps = pd.read_csv('mouse_mps_summary.csv')
df_mouse_mps.shape
# Out:
# (33, 8)

# %%
df_rat_pa = pd.read_csv('rat_pa_summary.csv')
df_rat_pa.shape
# Out:
# (83, 8)

# %%
df_rat_sterile_baseline = pd.read_csv('rat_sterile_baseline_summary.csv')
df_rat_sterile_baseline.shape
# Out:
# (51, 8)

# %%
df_rat_sterile_post_beads = pd.read_csv('rat_sterile_post_beads_summary.csv')
df_rat_sterile_post_beads.shape
# Out:
# (53, 8)

# %%
df_sheep_01_60 = pd.read_csv('sheep_01_60_summary.csv')
df_sheep_01_60.shape
# Out:
# (62, 8)

# %%
# Correlation between features
# Pearson product-moment correlation coefficients

plt.figure(figsize=(15,15))
cm = np.corrcoef(df_post.iloc[:,3:8].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 25}, cmap='viridis',yticklabels=df_post.columns[3:8], xticklabels=df_post.columns[3:8])
hm.set_title("Correlation between features post asthma")
plt.show()

# %% [markdown]
# # Pre asthma

# %%
df_pre = pd.read_csv('pre_sheep_asthma.csv')
df_pre
# Out:
#                                             ScanName  VDP(%)  MSV(mL/mL)  \
# 0   ATEAM-919-PC_XV_INSP-Sheep_KG_78_KG_78-PreBronch    22.4      0.1260
# 1   ATEAM-916-PC_XV_INSP-Sheep_KG_75_KG_75-PreBronch    24.8      0.0940
# 2                                ATEAM-911-KG_69-PRE    19.9      0.1347
# 3                                ATEAM-913-KG_72-PRE    20.0      0.1030
# 4   ATEAM-907-PC_XV_INSP-Sheep_KG_62_KG_62-PreBronch    21.4      0.1420
# 5                                ATEAM-909-KG_64-PRE    16.0      0.0981
# 6   ATEAM-918-PC_XV_INSP-Sheep_KG_77_KG_77-PreBronch    21.1      0.1200
# 7                                ATEAM-910-KG_67-PRE    22.3      0.1220
# 8   ATEAM-899-PC_XV_INSP-Sheep_KG_61_KG_61-PreBronch    20.3      0.1290
# 9                                ATEAM-908-KG_63-PRE    23.8      0.1400
# 10                               ATEAM-914-KG_73-PRE    21.5      0.1580
# 11  ATEAM-915-PC_XV_INSP-Sheep_KG_74_KG_74-PreBronch    21.4      0.1510
# ...

# %%
# Correlation between features
# Pearson product-moment correlation coefficients

plt.figure(figsize=(15,15))
cm = np.corrcoef(df_pre.iloc[:,2:7].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 25}, cmap='viridis',yticklabels=df_pre.columns[2:7], xticklabels=df_pre.columns[2:7])
hm.set_title("Correlation between features of pre_asthma")
plt.show()

# %%
df_mouse_b_enac = pd.read_csv('mouse_b_enac_summary.csv')
df_mouse_b_enac
# Out:
#          ScanName               Date Prepared  VDP(%)  MSV(mL/mL)  TV(L)  \
# 0   MAL-006501_XV  2023-08-23-15:57:40.904971   15.30       0.357  0.289
# 1   MAL-006533_XV  2023-08-23-15:54:10.777130   15.60       0.378  0.245
# 2   MAL-006531_XV  2023-08-23-15:49:03.475248   14.70       0.390  0.262
# 3   MAL-006524_XV  2023-08-23-15:53:24.209860   12.00       0.334  0.245
# 4   MAL-006583_XV  2023-08-23-15:52:50.404602   16.90       0.276  0.134
# 5   MAL-006504_XV  2023-08-23-15:53:56.931235   12.90       0.367  0.197
# 6   MAL-006499_XV  2023-08-23-15:51:01.770129   11.20       0.333  0.239
# 7   MAL-006500_XV  2023-08-23-15:50:15.040569   12.10       0.363  0.240
# 8   MAL-006498_XV  2023-08-23-15:52:35.049030   16.20       0.337  0.342
# 9   MAL-006502_XV  2023-08-23-15:54:34.799341   14.40       0.381  0.210
# 10  MAL-006519_XV  2023-08-23-15:50:00.656468   11.80       0.333  0.249
# 11  MAL-006503_XV  2023-08-23-15:57:16.651112   17.60       0.345  0.268
# ...

# %%
df_mouse_b_enac_new = df_mouse_b_enac.drop_duplicates(subset=['VDP(%)', 'MSV(mL/mL)', 'TV(L)', 'VH(%)', 'VHSS(%)','VHLS(%)'])

# %%
len(df_mouse_b_enac_new)
# Out:
# 28

# %%
df_mouse_b_enac_new.to_csv("mouse_b_enac_summary_new.csv", index=False)
